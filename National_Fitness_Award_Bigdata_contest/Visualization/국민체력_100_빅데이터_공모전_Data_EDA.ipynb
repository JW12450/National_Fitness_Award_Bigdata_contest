# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings(action='ignore')

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (7,955 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ## 체력측정 항목별 측정 데이터
#
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=ace0aea7-5eee-48b9-b616-637365d665c1

# %%
df = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/체력측정 항목별 측정 데이터/KS_NFA_FTNESS_MESURE_ITEM_MESURE_INFO_202107.csv')
df
# Out:
#        TEST_CNT CENTER_NM AGE_GBN  ... ITEM_F039  ITEM_F040 ITEM_F041
# 0             2        목포      성인  ...       NaN      0.365       NaN
# 1             4    동구(광주)      성인  ...       NaN      0.350       NaN
# 2             1        제주      성인  ...       NaN      0.326       NaN
# 3             1        강북      성인  ...       NaN      0.391       NaN
# 4             4        오산      노인  ...       NaN        NaN       NaN
# ...         ...       ...     ...  ...       ...        ...       ...
# 11248         1    KSPO송파      성인  ...       NaN      0.370       NaN
# 11249         1    KSPO대구     청소년  ...       NaN        NaN       NaN
# 11250         4    KSPO대구     청소년  ...       NaN        NaN       NaN
# 11251         1    KSPO아산      성인  ...       NaN      0.338       NaN
# 11252         1    동구(부산)      성인  ...       NaN      0.371       NaN
#
# [11253 rows x 50 columns]

# %% [markdown]
# 순서	컬럼영문명	컬럼한글명	데이터타입	길이	PK여부	NOT NULL여부
#
# 1	TEST_CNT	측정 회차	NUMERIC	22		10MY
#
# 2	CENTER_NM	센터명	VARCHAR	100
#
# 3	AGE_GBN	나이구분	VARCHAR	20		Y
#
# 4	TEST_GBN	측정구분	VARCHAR	20
#
# 5	TEST_AGE	측정나이	NUMERIC	22
# 6	INPUT_GBN	입력구분	VARCHAR	20
# 7	CERT_GBN	상장구분	VARCHAR	20
# 8	TEST_YMD	측정일	CHAR	8		Y
# 9	TEST_SEX	측정회원성별	CHAR	1
# 10	ITEM_F001	측정항목값 : 신장 : cm
# 11	ITEM_F002	측정항목값 : 체중 : kg	VARCHAR	100
# 12	ITEM_F003	측정항목값 : 체지방율 : %	VARCHAR	100
# 13	ITEM_F004	측정항목값 : 허리둘레 : cm	VARCHAR	100
# 14	ITEM_F005	측정항목값 : 이완기혈압(최저) : mmHg	VARCHAR	100
# 15	ITEM_F006	측정항목값 : 수축기혈압(최고) : mmHg	VARCHAR	100
# 16	ITEM_F007	측정항목값 : 악력D : kg	VARCHAR	100
# 17	ITEM_F008	측정항목값 : 악력ND : kg	VARCHAR	100
# 18	ITEM_F009	측정항목값 : 윗몸말아올리기 : 회	VARCHAR	100
# 19	ITEM_F010	측정항목값 : 반복점프 : 회	VARCHAR	100
# 20	ITEM_F011	미정	VARCHAR	100
# 21	ITEM_F012	측정항목값 : 앉아윗몸앞으로굽히기 : cm	VARCHAR	100
# 22	ITEM_F013	측정항목값 : 일리노이 : 초	VARCHAR	100
# 23	ITEM_F014	측정항목값 : 체공시간 : 초	VARCHAR	100
# 24	ITEM_F015	측정항목값 : 협응력시간 : 초	VARCHAR	100
# 25	ITEM_F016	측정항목값 : 협응력실수횟수 : 회	VARCHAR	100
# 26	ITEM_F017	측정항목값 : 협응력계산결과값 : 초	VARCHAR	100
# 27	ITEM_F018	측정항목값 : BMI : kg/㎡	VARCHAR	100
# 28	ITEM_F019	측정항목값 : 교차윗몸일으키기 : 회	VARCHAR	100
# 29	ITEM_F020	측정항목값 : 왕복오래달리기 : 회	VARCHAR	100
# 30	ITEM_F021	측정항목값 : 10M 4회 왕복달리기 : 초	VARCHAR	100
# 31	ITEM_F022	측정항목값 : 제자리 멀리뛰기 : cm	VARCHAR	100
# 32	ITEM_F023	측정항목값 : 의자에앉았다일어서기 : 회	VARCHAR	100
# 33	ITEM_F024	측정항목값 : 6분걷기 : m	VARCHAR	100
# 34	ITEM_F025	측정항목값 : 2분제자리걷기 : 회	VARCHAR	100
# 35	ITEM_F026	측정항목값 : 의자에앉아 3M표적 돌아오기 : 초	VARCHAR	100
# 36	ITEM_F027	측정항목값 : 8자보행 : 초	VARCHAR	100
# 37	ITEM_F028	측정항목값 : 상대악력 : %	VARCHAR	100
# 38	ITEM_F029	측정항목값 : 피두부겹합	VARCHAR	100
# 39	ITEM_F030	측정항목값 : 왕복오래달리기(출력) : VO₂max	VARCHAR	100
# 40	ITEM_F031	측정항목값 : 트레드밀_안정시 : bpm	VARCHAR	100
# 41	ITEM_F032	측정항목값 : 트레드밀_3분 : bpm	VARCHAR	100
# 42	ITEM_F033	측정항목값 : 트레드밀_6분 : bpm	VARCHAR	100
# 43	ITEM_F034	측정항목값 : 트레드밀_9분 : bpm	VARCHAR	100
# 44	ITEM_F035	측정항목값 : 트레드밀(출력) : VO₂max	VARCHAR	100
# 45	ITEM_F036	측정항목값 : 스텝검사_회복시 심박수 : bpm	VARCHAR	100
# 46	ITEM_F037	측정항목값 : 스텝검사(출력) : VO₂max	VARCHAR	100
# 47	ITEM_F038	측정항목값 : 허벅지(좌)	VARCHAR	100
# 48	ITEM_F039	측정항목값 : 허벅지(우)	VARCHAR	100
# 49	ITEM_F040	측정항목값 : 전신반응 : 초	VARCHAR	100
# 50	ITEM_F041	측정항목값 : 체공시간2 : 초	VARCHAR	100

# %% [markdown]
# ### 결측치 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11253 entries, 0 to 11252
# Data columns (total 50 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TEST_CNT   11253 non-null  int64
#  1   CENTER_NM  11253 non-null  object
#  2   AGE_GBN    11253 non-null  object
#  3   TEST_GBN   11253 non-null  object
#  4   TEST_AGE   11253 non-null  int64
#  5   INPUT_GBN  9858 non-null   object
#  6   CERT_GBN   11251 non-null  object
#  7   TEST_YMD   11253 non-null  int64
#  8   TEST_SEX   11253 non-null  object
#  9   ITEM_F001  11253 non-null  float64
#  10  ITEM_F002  11253 non-null  float64
#  11  ITEM_F003  10769 non-null  float64
#  12  ITEM_F004  7050 non-null   float64
#  13  ITEM_F005  11253 non-null  float64
#  14  ITEM_F006  11253 non-null  float64
#  15  ITEM_F007  11061 non-null  float64
#  16  ITEM_F008  11066 non-null  float64
#  17  ITEM_F009  1740 non-null   float64
#  18  ITEM_F010  1861 non-null   float64
# ...

# %%
print("---------결측값 비율---------")
print((df.isnull().sum() / len(df))*100)
# Out:
# ---------결측값 비율---------
# TEST_CNT       0.000000
# CENTER_NM      0.000000
# AGE_GBN        0.000000
# TEST_GBN       0.000000
# TEST_AGE       0.000000
# INPUT_GBN     12.396694
# CERT_GBN       0.017773
# TEST_YMD       0.000000
# TEST_SEX       0.000000
# ITEM_F001      0.000000
# ITEM_F002      0.000000
# ITEM_F003      4.301075
# ITEM_F004     37.350040
# ITEM_F005      0.000000
# ITEM_F006      0.000000
# ITEM_F007      1.706212
# ITEM_F008      1.661779
# ITEM_F009     84.537457
# ITEM_F010     83.462188
# ITEM_F011    100.000000
# ITEM_F012      1.181907
# ITEM_F013     73.207145
# ITEM_F014     72.860571
# ITEM_F015     72.167422
# ITEM_F016     72.167422
# ITEM_F017     72.122989
# ITEM_F018      0.000000
# ITEM_F019     44.148227
# ITEM_F020     82.866791
# ITEM_F021     97.334044
# ITEM_F022     42.113214
# ITEM_F023     89.753843
# ITEM_F024     99.795610
# ITEM_F025     89.967120
# ITEM_F026     89.664978
# ITEM_F027     89.718297
# ITEM_F028      1.555141
# ...

# %% [markdown]
# ### 범주형 칼럼 항목 확인

# %%
print("---TEST_CNT---\n",df["TEST_CNT"].unique())
print("\n---CENTER_NM---\n",df["CENTER_NM"].unique())
print("\n---AGE_GBN---\n",df["AGE_GBN"].unique())
print("\n---TEST_GBN---\n",df["TEST_GBN"].unique())
print("\n---AGE_GBN---\n",df["CERT_GBN"].unique())
# Out:
# ---TEST_CNT---
#  [ 2  4  1  3  6  8  7  9 13  5 35 14 10 20 12 11 18 19 34 48 38 24 36 15
#  25 27 21 31 37 16 17 33 30]
#
# ---CENTER_NM---
#  ['목포' '동구(광주)' '제주' '강북' '오산' 'KSPO아산' 'KSPO송파' '서구(광주)' '광산' '안산' '구미'
#  '남구(울산)' '동구(인천)' '스포원(금정)' '경산' '전주' '동작' '신안' 'KSPO송파(출장A)' '창원마산회원'
#  '사상' '춘천' '세종' '청주' '보은' '계룡' 'KSPO대구(출장A)' '원주' '영동' '북구(광주)'
#  'KSPO대구(출장B)' 'KSPO광주' 'KSPO아산(출장)' '동구(부산)' '서대문' '양평' '광주' '남구(부산)'
#  '증평' '순천' '안동' '서초' '의정부' '곡성' '고양' '포항' '중구(서울)' '성남' '달서' 'KSPO대구' '화성'
#  '서구(대전)' '영주' '정읍' '마포' '사하' '천안' '창원' '태백' '시흥' '미추홀' '김천' '무안' '사천'
#  '군산' '강릉' '연제' '익산' '수원' '삼척' '영암' 'KSPO광주(출장)' '진천' '포천' '충주' '나주' '부천'
#  '연수' '남원']
#
# ---AGE_GBN---
#  ['성인' '노인' '청소년' '유소년']
#
# ---TEST_GBN---
#  ['일반' '출장']
#
# ---AGE_GBN---
#  ['참가증' '3등급' '2등급' '1등급' nan]

# %%
df["AGE_GBN"].value_counts()
# Out:
# 성인     6438
# 청소년    3149
# 노인     1189
# 유소년     477
# Name: AGE_GBN, dtype: int64

# %%
f, ax = plt.subplots(1,2, figsize=(12,6))
df['AGE_GBN'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0], shadow=True)
sns.countplot("AGE_GBN", data = df, ax = ax[1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### 결측값들 처리 생각해보기
#
#
# 7 CERT_GBN 상장구분 VARCHAR 20 -> 굳이 필요 없을듯
#
# 13 ITEM_F004 측정항목값 : 허리둘레 : cm VARCHAR 100
#
# 18 ITEM_F009 측정항목값 : 윗몸말아올리기 : 회 VARCHAR 1000   0.84%가 결측값
#
# ... 이건 나중에 사용할 칼럼 확정되면 더

# %%
import missingno as msno
msno.matrix(df=df, figsize=(30,8), color=(70/255, 172/255, 161/255))

# %% [markdown]
# 국민체력 100 인증기준에 필요한
#
# 15m 왕복오래달리기(F020), 상대악력(F028), 윗몸말아올리기(F009), 윗몸앞으로 굽히기(F012), 반복 옆뛰기, 제자리 멀리뛰기, 눈-손 협응력 검사
#
# **유소년기, 청소년기, 성인기, 어르신 모두 각기 다른 평가 항목**
#
# *나이대별로 나눠서 접근해야 할 듯 혹은 특정 나이대만 접근해봐도 좋을 듯*
#
# Ex) 어르신(65세 이상)들의 체력 측정 종목별 분포 시각화, 측정 종목별 상관관계 분석
#
# 항목별 다중공산성 체크 -> 다중회귀 모델 구현

# %%
df_elderly = df[df['AGE_GBN'] == "노인"]
df_elderly
# Out:
#        TEST_CNT CENTER_NM AGE_GBN  ... ITEM_F039  ITEM_F040 ITEM_F041
# 4             4        오산      노인  ...       NaN        NaN       NaN
# 7             3    서구(광주)      노인  ...       NaN        NaN       NaN
# 11            1    남구(울산)      노인  ...       NaN        NaN       NaN
# 16            1        전주      노인  ...       NaN        NaN       NaN
# 27            1    서구(광주)      노인  ...       NaN        NaN       NaN
# ...         ...       ...     ...  ...       ...        ...       ...
# 11175         1    KSPO송파      노인  ...       NaN        NaN       NaN
# 11187         1       미추홀      노인  ...       NaN        NaN       NaN
# 11203         1        연수      노인  ...       NaN        NaN       NaN
# 11219         1    KSPO송파      노인  ...       NaN        NaN       NaN
# 11240         1        양평      노인  ...       NaN        NaN       NaN
#
# [1189 rows x 50 columns]

# %%
df_elderly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1189 entries, 4 to 11240
# Data columns (total 50 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TEST_CNT   1189 non-null   int64
#  1   CENTER_NM  1189 non-null   object
#  2   AGE_GBN    1189 non-null   object
#  3   TEST_GBN   1189 non-null   object
#  4   TEST_AGE   1189 non-null   int64
#  5   INPUT_GBN  1076 non-null   object
#  6   CERT_GBN   1189 non-null   object
#  7   TEST_YMD   1189 non-null   int64
#  8   TEST_SEX   1189 non-null   object
#  9   ITEM_F001  1189 non-null   float64
#  10  ITEM_F002  1189 non-null   float64
#  11  ITEM_F003  1189 non-null   float64
#  12  ITEM_F004  707 non-null    float64
#  13  ITEM_F005  1189 non-null   float64
#  14  ITEM_F006  1189 non-null   float64
#  15  ITEM_F007  1175 non-null   float64
#  16  ITEM_F008  1176 non-null   float64
#  17  ITEM_F009  0 non-null      float64
#  18  ITEM_F010  0 non-null      float64
# ...

# %%
plt.rc("ytick", labelsize = 15)
fig, ax = plt.subplots(1, 1, figsize=(16, 8))
sns.kdeplot(df_elderly[df_elderly['CERT_GBN'] == '1등급']['ITEM_F025'], ax=ax)
sns.kdeplot(df_elderly[df_elderly['CERT_GBN'] == '2등급']['ITEM_F025'], ax=ax)
sns.kdeplot(df_elderly[df_elderly['CERT_GBN'] == '3등급']['ITEM_F025'], ax=ax)
plt.legend(['1등급', '2등급' '3등급'])
plt.title('노인들의 체력 등급별 2분걷기(ITEM_F025) 비교')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# Standardization 평균 0 / 분산 1
scaler = StandardScaler()

# %%
df_ml = df_elderly[['ITEM_F012', 'ITEM_F018', 'ITEM_F023', 'ITEM_F025', 'ITEM_F026', 'ITEM_F027','ITEM_F028']]

#df_ml = pd.get_dummies(df_ml, columns=['ITEM_F012', 'ITEM_F018', 'ITEM_F023', 'ITEM_F025', 'ITEM_F026', 'ITEM_F027','ITEM_F028',], drop_first=True)
# 필요없는 column과 na값 drop
#df_ml.drop(['PassengerId','Name','Ticket', 'Cabin'],axis=1,inplace=True)
df_ml.dropna(inplace=True)
scaler = scaler.fit_transform(df_ml)

sns.set(font_scale = 0.7)
sns.set(rc = {'figure.figsize':(15,8)})
ax = sns.heatmap(df_ml.corr(), annot = True, fmt = ".2f", linewidths = 1, cmap="crest")
buttom, top = ax.get_ylim()
ax.set_ylim(buttom + 0.5, top - 0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (7.5, -0.5)

# %% [markdown]
# ### 노인 체력 측정항목별 상관관계 분석
#
# ex) F025와 F026의 상관관계 높음
#
# 34 ITEM_F025 측정항목값 : 2분제자리걷기 <-> 35 ITEM_F026 측정항목값 : 의자에앉아 3M표적 돌아오기

# %% [markdown]
# ### 추가 논의 사항
#
# -
#
# -
#
# -
#
# -

# %% [markdown]
# ## 체력 측정별 운동처방 데이터
#
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=2b1c565d-5f37-4152-966d-5f8094f8cf33

# %%
df1 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/체력 측정별 운동처방 데이터/KS_NFA_FTNESS_MESURE_MVM_PRSCRPTN_INFO_202107.csv')
df1
# Out:
#       TEST_CNT  ... TEST_SEX
# 0            1  ...        F
# 1            1  ...        F
# 2            1  ...        M
# 3            1  ...        F
# 4            1  ...        F
# ...        ...  ...      ...
# 9438         2  ...        M
# 9439         1  ...        M
# 9440         1  ...        M
# 9441         2  ...        M
# 9442         1  ...        M
#
# [9443 rows x 10 columns]

# %% [markdown]
# 컬럼정의서 시트
# 순서	컬럼영문명	컬럼한글명	데이터타입	길이	PK여부	NOT NULL여부
#
# 1	TEST_CNT	측정 회차	NUMERIC	22		Y
#
# 2	CENTER_NM	센터명	VARCHAR	100
#
# 3	AGE_GBN	나이구분	VARCHAR	20		Y
#
# 4	TEST_GBN	측정구분	VARCHAR	20
#
# 5	TEST_AGE	측정나이	NUMERIC	22
#
# 6	INPUT_GBN	입력구분	VARCHAR	20
#
# 7	CERT_GBN	상장구분	VARCHAR	20
#
# 8	TEST_YMD	측정일	CHAR	8		Y
#
# 9	PRES_NOTE	운동처방	TEXT			Y
#
# 10	TEST_SEX	측정회원성별	CHAR	1

# %%
df1['PRES_NOTE']
# Out:
# 0       본운동:엎드려 버티기,옆으로 누워 버티기,누워서 엉덩이 들어올리기,팔굽혀펴기,네발기...
# 1       준비운동:팔벌려뛰기,버피운동,한발 앞으로 내밀고 앉았다 일어서기,서서 균형잡기,옆으...
# 2       준비운동:팔벌려뛰기,버피운동,한발 앞으로 내밀고 앉았다 일어서기,서서 균형잡기,옆으...
# 3       준비운동:허리 스트레칭,엉덩이 스트레칭,넙다리 뒤쪽 스트레칭,누워서 굽힌 다리 펴기...
# 4       본운동:앉아서 다리 밀기,앉아서 다리 펴기,앉아서 다리 굽히기,앉았다 일어서기,엎드...
#                               ...
# 9438                              준비운동:팔꿈치 굽히기,윗몸올리기 ,줄넘기
# 9439    본운동:앉아서 다리 밀기,앉아서 다리 펴기,앉아서 다리 굽히기,앉았다 일어서기,엎드...
# 9440    준비운동:팔벌려뛰기,버피운동,한발 앞으로 내밀고 앉았다 일어서기,서서 균형잡기,옆으...
# 9441                                 준비운동:줄넘기,하지 루틴 스트레칭2
# 9442    준비운동:팔벌려뛰기,버피운동,한발 앞으로 내밀고 앉았다 일어서기,서서 균형잡기,옆으...
# Name: PRES_NOTE, Length: 9443, dtype: object

# %% [markdown]
# 준비운동, 본운동 모두 추천해줄때가 있고,
# 둘중 하나만 추천해주는 경우도 있음
#
# 쓸만하게 데이터셋 변형하려면 본운동 따로, 준비운동 따로 분리
# 그 내에서도 각각 운동별로 칼럼화(One-hot Encoding) 해야할듯..
#
# 엄청 번거로운 작업이라, 꼭 필요한거 아니면 굳이 할 필욘 X

# %% [markdown]
# ## 국민체력 측정 현황 데이터
#
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=c99df919-f2c9-4ceb-999d-82688c028031

# %%
df2 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/국민체력 측정 현황 데이터/KS_NFA_FTNESS_MESURE_STTUS_202107.csv')
df2
# Out:
#        TEST_CNT CENTER_NM AGE_GBN  ... CERT_GBN  TEST_YMD TEST_SEX
# 0             1    남구(울산)      성인  ...      참가증  20210701        F
# 1             4    KSPO송파      노인  ...      2등급  20210702        M
# 2             1    창원마산회원     청소년  ...      2등급  20210701        F
# 3             2        보은      성인  ...      참가증  20210701        F
# 4             1        동작      노인  ...      3등급  20210701        F
# ...         ...       ...     ...  ...      ...       ...      ...
# 11248         6        익산      성인  ...      참가증  20210723        F
# 11249         1       서대문     청소년  ...      참가증  20210712        M
# 11250         4    동구(인천)      성인  ...      참가증  20210712        M
# 11251         1        연제      성인  ...      참가증  20210712        M
# 11252         2    동구(인천)     청소년  ...      2등급  20210712        F
#
# [11253 rows x 9 columns]

# %% [markdown]
# 순서	컬럼영문명	컬럼한글명	데이터타입	길이	PK여부	NOT NULL여부
#
# 1	TEST_CNT	측정 회차	NUMERIC	22		Y
#
# 2	CENTER_NM	센터명	VARCHAR	100
#
# 3	AGE_GBN	나이구분	VARCHAR	20		Y
#
# 4	TEST_GBN	측정구분	VARCHAR	20
#
# 5	TEST_AGE	측정나이	NUMERIC	22
#
# 6	INPUT_GBN	입력구분	VARCHAR	20
#
# 7	CERT_GBN	상장구분	VARCHAR	20
#
# 8	TEST_YMD	측정일	CHAR	8		Y
#
# 9	TEST_SEX	측정회원성별	CHAR	1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11253 entries, 0 to 11252
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TEST_CNT   11253 non-null  int64
#  1   CENTER_NM  11253 non-null  object
#  2   AGE_GBN    11253 non-null  object
#  3   TEST_GBN   11253 non-null  object
#  4   TEST_AGE   11253 non-null  int64
#  5   INPUT_GBN  9858 non-null   object
#  6   CERT_GBN   11251 non-null  object
#  7   TEST_YMD   11253 non-null  int64
#  8   TEST_SEX   11253 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 791.4+ KB

# %% [markdown]
# ### 데이터셋이 결측치 없이 깔끔해서 한 20달치 데이터셋 끌어모아서 시각화 하기 적합함
#
# 성별, 나이대별, 지역별 등급 확인 가능

# %%
df2.groupby(['CERT_GBN','TEST_SEX'])['CERT_GBN'].count()
# Out:
# CERT_GBN  TEST_SEX
# 1등급       F            333
#           M            456
# 2등급       F            674
#           M           1149
# 3등급       F            969
#           M           1443
# 참가증       F           2756
#           M           3471
# Name: CERT_GBN, dtype: int64

# %%
f, ax = plt.subplots(1, 1, figsize=(14, 5))
sns.countplot('TEST_SEX', hue='CERT_GBN', data=df2) #hue: 나누어서 보고싶은 구분변수기준

# %% [markdown]
# ## 국민연령별추천운동정보
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=93297f90-2594-11eb-af9a-4b03f0a582d6

# %%
df3 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/국민연령별추천운동정보/KS_MRFN_AGE_ACCTO_RECOMMEND_SPORTS_INFO_202107.csv')
df3
# Out:
#      AGRDE_FLAG_NM  ...      RECOMEND_MVM_NM
# 0              10대  ...           상지 루틴 스트레칭
# 1              10대  ...  유산소 운동 전 동적 루틴 스트레칭
# 2              10대  ...         등/어깨 뒤쪽 스트레칭
# 3              10대  ...               팔굽혀 펴기
# 4              10대  ...                윗몸올리기
# ...            ...  ...                  ...
# 5035        70대 이상  ...         양팔 벌려 전신 비틀기
# 5036        70대 이상  ...         깍지 끼고 상체 숙이기
# 5037        70대 이상  ...              어깨 스트레칭
# 5038        70대 이상  ...                   수영
# 5039        70대 이상  ...         짐볼에서 윗몸 일으키기
#
# [5040 rows x 7 columns]

# %%
df3[:30]
# Out:
#    AGRDE_FLAG_NM  ...       RECOMEND_MVM_NM
# 0            10대  ...            상지 루틴 스트레칭
# 1            10대  ...   유산소 운동 전 동적 루틴 스트레칭
# 2            10대  ...          등/어깨 뒤쪽 스트레칭
# 3            10대  ...                팔굽혀 펴기
# 4            10대  ...                 윗몸올리기
# 5            10대  ...               엎드려 버티기
# 6            10대  ...              앉았다 일어서기
# 7            10대  ...                   줄넘기
# 8            10대  ...           하지 루틴 스트레칭2
# 9            10대  ...            전신 루틴 스트레칭
# 10           10대  ...            상지 루틴 스트레칭
# 11           10대  ...             양발 나란히 서기
# 12           10대  ...              점프 후 버티기
# 13           10대  ...  벌림 밸런스 운동-60~120도 사이
# 14           10대  ...                    조깅
# 15           10대  ...                목 스트레칭
# 16           10대  ...              엉덩이 스트레칭
# 17           10대  ...                목 스트레칭
# 18           10대  ...   유산소 운동 전 동적 루틴 스트레칭
# 19           10대  ...            전신 루틴 스트레칭
# ...

# %%
df3_def = pd.read_excel('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/국민연령별추천운동정보/국민연령별추천운동정보_컬럼정의서.xls')
df3_def

##데이터 정의서
# Out:
#    순서                          컬럼영문명      컬럼한글명    데이터타입   길이 PK여부 NOT NULL여부
# 0   1                       AGRDE_SE      연령대구분  VARCHAR   30    Y          Y
# 1   2                  BMI_IDEX_GRAD    BMI지수등급  VARCHAR   30    Y          Y
# 2   3                MBER_SEXDSTN_SE     회원성별구분  VARCHAR   30    Y          Y
# 3   4                        COAW_SE       상장구분  VARCHAR   30    Y          Y
# 4   5                 SPORTS_STEP_NM      운동단계명  VARCHAR  200    Y          Y
# 5   6  SE_ACCTO_RECOMEND_SPORTS_RANK  구분별추천운동순위  NUMERIC   30    Y          Y
# 6   7             RECOMEND_SPORTS_NM      추천운동명  VARCHAR  200  NaN        NaN

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5040 entries, 0 to 5039
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   AGRDE_FLAG_NM                    5040 non-null   object
#  1   BMI_IDEX_GRAD_NM                 5040 non-null   object
#  2   MBER_SEXDSTN_FLAG_CD             5040 non-null   object
#  3   COAW_FLAG_NM                     5040 non-null   object
#  4   SPORTS_STEP_NM                   5040 non-null   object
#  5   FLAG_ACCTO_RECOMEND_MVM_RANK_CO  5040 non-null   int64
#  6   RECOMEND_MVM_NM                  5040 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 275.8+ KB

# %%
df3['RECOMEND_MVM_NM'].describe()
# Out:
# count       5040
# unique       377
# top       목 스트레칭
# freq         268
# Name: RECOMEND_MVM_NM, dtype: object

# %%
df3.groupby(['RECOMEND_MVM_NM']).count().sort_index(ascending=True)
# Out:
#                     AGRDE_FLAG_NM  ...  FLAG_ACCTO_RECOMEND_MVM_RANK_CO
# RECOMEND_MVM_NM                    ...
# V자 싸이클                          2  ...                                2
# 가슴 스트레칭                         1  ...                                1
# 가슴 어깨 펴기                       43  ...                               43
# 가슴/어깨 스트레칭                      1  ...                                1
# 가슴/어깨 앞쪽 스트레칭                  30  ...                               30
# ...                           ...  ...                              ...
# 허리숙여 양팔 돌리기                     2  ...                                2
# 협응력 향상 프로그램_계이름 치기              3  ...                                3
# 회전 초승달 자세                       1  ...                                1
# 회전근개 스트레칭2                      1  ...                                1
# 휴식자세                            1  ...                                1
#
# [377 rows x 6 columns]

# %%
pd.value_counts(df3['RECOMEND_MVM_NM'].values, sort=True)
# Out:
# 목 스트레칭              268
# 상지 루틴 스트레칭          194
# 전신 루틴 스트레칭          189
# 하지 루틴 스트레칭1         174
# 몸통 들어올리기            166
#                    ...
# 의자에 앉아 가슴 뒤로 젖히기      1
# 나무자세                  1
# 사이드 한발 뛰기             1
# 회전근개 스트레칭2            1
# 테스트2                  1
# Length: 377, dtype: int64

# %% [markdown]
# 총 377개의 운동 추천
#
# 나이대, 비만 정도, 성별, 신체 등급, 준비/본 운동 여부에 따른 추천 운동
#
# 다른 데이터셋이랑 결합해서 사용 가능할듯!?

# %% [markdown]
# ## 국민유형별걷기분석정보
#
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=10eb0f80-2594-11eb-af9a-4b03f0a582d6

# %%
df4 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/국민유형별걷기분석정보/KS_MRFN_TY_ACCTO_WALK_ANALS_INFO_202107.csv')
df4_def = pd.read_excel('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/국민유형별걷기분석정보/국민유형별걷기분석정보_컬럼정의서.xls')
df4
# Out:
#     MESURE_AGRDE_FLAG_NM SEXDSTN_FLAG_CD  ... MESURE_NMPR_CO  AVRG_PACE_CO
# 0                    10대               F  ...             58          4504
# 1                    10대               F  ...             62          4658
# 2                    10대               F  ...             59          4165
# 3                    10대               F  ...             62          3677
# 4                    10대               F  ...             60          5997
# ..                   ...             ...  ...            ...           ...
# 387               70대 이상               M  ...            368         12443
# 388               70대 이상               M  ...            366         12008
# 389               70대 이상               M  ...            354         12807
# 390               70대 이상               M  ...            352         12618
# 391               70대 이상               M  ...            243         12940
#
# [392 rows x 6 columns]

# %%
df4_def
# Out:
#    순서            컬럼영문명    컬럼한글명    데이터타입   길이 PK여부 NOT NULL여부
# 0   1  MESURE_AGRDE_SE  측정연령대구분  VARCHAR   30    Y          Y
# 1   2       SEXDSTN_SE     성별구분  VARCHAR   30    Y          Y
# 2   3         WEEK_ODR      주차수  VARCHAR  200    Y          Y
# 3   4         DALY_ODR     일별차수  VARCHAR  200    Y          Y
# 4   5   MESURE_NMPR_CO    측정인원수  NUMERIC   50  NaN        NaN
# 5   6     AVRG_PACE_CO    평균걸음수  NUMERIC   50  NaN        NaN

# %% [markdown]
# 활용가능한 빅데이터가 아닌듯.....

# %%
df4[df4['MESURE_AGRDE_FLAG_NM'] == '10대']
# Out:
#    MESURE_AGRDE_FLAG_NM SEXDSTN_FLAG_CD  ... MESURE_NMPR_CO  AVRG_PACE_CO
# 0                   10대               F  ...             58          4504
# 1                   10대               F  ...             62          4658
# 2                   10대               F  ...             59          4165
# 3                   10대               F  ...             62          3677
# 4                   10대               F  ...             60          5997
# 5                   10대               F  ...             60          4177
# 6                   10대               F  ...             57          3288
# 7                   10대               F  ...             58          3633
# 8                   10대               F  ...             59          3697
# 9                   10대               F  ...             59          3095
# 10                  10대               F  ...             60          3507
# 11                  10대               F  ...             59          3698
# ...

# %% [markdown]
# ## 체력인증센터 걷기정보
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=fe651630-2593-11eb-af9a-4b03f0a582d6
#
# - 웨어러블 디바이스 기기로부터 걷기데이터를 수집하여 서울올림픽기념국민체육진흥공단에서 관리하고 있는 체력인증센터 걷기 정보에 대한 정보를 제공하는 데이터입니다.
# 회원의 연령, 성별 정보와 4주간의 주차별 일차별 걸음수에 대한 정보 등을 조회할 수 있습니다.

# %%
df5 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/체력인증센터 걷기정보/KS_FCC_WALK_INFO_202107.csv')
df5_def = pd.read_excel('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/체력인증센터 걷기정보/체력인증센터걷기정보_컬럼정의서.xls')
df5
# Out:
#         MBER_AGE_CO SEXDSTN_FLAG_CD WEEK_ODR  DALY_ODR  PACE_CO  CNSUM_CAL
# 0                10               M    WK_01         6  13205.0          0
# 1                10               M    WK_03         1   9890.0          0
# 2                10               M    WK_01         7  12404.0          0
# 3                10               M    WK_01         1  11117.0          0
# 4                10               M    WK_04         5  15528.0          0
# ...             ...             ...      ...       ...      ...        ...
# 782859           87               F    WK_03         3   3604.0          0
# 782860           87               F    WK_03         4   6171.0          0
# 782861           87               F    WK_04         4     32.0          0
# 782862           87               F    WK_04         5   7360.0          0
# 782863           87               F    WK_04         6     63.0          0
#
# [782864 rows x 6 columns]

# %%
df5_def
# Out:
#    순서       컬럼영문명 컬럼한글명    데이터타입   길이  PK여부  NOT NULL여부
# 0   1    MBER_AGE  회원연령  NUMERIC   50   NaN         NaN
# 1   2  SEXDSTN_SE  성별구분  VARCHAR   30   NaN         NaN
# 2   3    WEEK_ODR   주차수  VARCHAR  200   NaN         NaN
# 3   4    DALY_ODR  일별차수  VARCHAR  200   NaN         NaN
# 4   5     PACE_CO   걸음수  NUMERIC   50   NaN         NaN
# 5   6   CNSUM_CAL  소모열량  NUMERIC   30   NaN         NaN

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782864 entries, 0 to 782863
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   MBER_AGE_CO      782864 non-null  int64
#  1   SEXDSTN_FLAG_CD  782864 non-null  object
#  2   WEEK_ODR         782864 non-null  object
#  3   DALY_ODR         782864 non-null  int64
#  4   PACE_CO          781438 non-null  float64
#  5   CNSUM_CAL        782864 non-null  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 35.8+ MB

# %% [markdown]
# ### 활용방안
#
# 어플을 통해 개인별 걸음수 파악 가능
#
# 일별 걸음 수, 소모 칼로리 파악 가능
#
# *문제점)*
# 회원이 구분이 되면 회원의 주차별, 일별 정리가 가능한데
# 데이터셋에 회원을 구분할 수 있는 칼럼이 없다...

# %% [markdown]
# ## 지역별 체력통계 데이터
#
# https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=baa2ebfb-2908-4943-a95e-19bce4e49a26
#
# - 서울올림픽기념 국민체육진흥공단에서 관리하고 있는 국민체력측정데이터의 지역별 체력측정 통계정보를 제공하는 데이터입니다.
# 지역별 체력측정결과 통계정보를 조회할 수 있습니다.

# %%
df6 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/지역별 체력통계 데이터/KS_NFA_FTNESS_STATS_INFO_AREA_202107.csv')
df6_def = pd.read_excel('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/지역별 체력통계 데이터/지역별 체력통계 데이터_컬럼정의서.xls')
df6
# Out:
#      CENTER_SD_CD CENTER_SD_NM  ...  TEST_AGE_SIXTIES TEST_AGE_OLDER70
# 0              11           서울  ...                 5                5
# 1              11           서울  ...                 1                0
# 2              11           서울  ...                12                9
# 3              11           서울  ...                 0                0
# 4              11           서울  ...               782              761
# ..            ...          ...  ...               ...              ...
# 116            48           경남  ...                 0                0
# 117            48           경남  ...               387              785
# 118            50           제주  ...                15                1
# 119            50           제주  ...               437              936
# 120            60           세종  ...               128              117
#
# [121 rows x 29 columns]

# %%
df6_def
# Out:
#     순서                   컬럼영문명        컬럼한글명    데이터타입  길이 PK여부 NOT NULL여부
# 0    1            CENTER_SD_CD      센터 시도코드  VARCHAR  10    Y          Y
# 1    2            CENTER_SD_NM       센터 시도명  VARCHAR  40  NaN          Y
# 2    3           CENTER_SGG_CD     센터 시군구코드  VARCHAR  10    Y          Y
# 3    4           CENTER_SGG_NM      센터 시군구명  VARCHAR  40  NaN          Y
# 4    5               TEST_YEAR         측정년도  VARCHAR   4    Y          Y
# 5    6            TEST_ALL_CNT         측정횟수  NUMERIC  22  NaN          Y
# 6    7                MEMB_CNT          회원수  NUMERIC  22  NaN          Y
# 7    8    AGE_GBN_CHILDREN_CNT     유소년 회원 수  NUMERIC  22  NaN          Y
# 8    9       AGE_GBN_YOUTH_CNT     청소년 회원 수  NUMERIC  22  NaN          Y
# 9   10       AGE_GBN_ADULT_CNT      성인 회원 수  NUMERIC  22  NaN          Y
# 10  11     AGE_GBN_CITIZEN_CNT      노인 회원 수  NUMERIC  22  NaN          Y
# 11  12     INPUT_GBN_ADMIN_CNT     관리자 입력건수  NUMERIC  22  NaN          Y
# ...

# %%
df6 = df6[['CENTER_SGG_CD', 'CERT_GBN_GOLD']]
df6
# Out:
#      CENTER_SGG_CD  CERT_GBN_GOLD
# 0            11440              3
# 1            11710              7
# 2            11650              7
# 3            11710              0
# 4            11650            310
# ..             ...            ...
# 116          48123              1
# 117          48123            224
# 118          50110              3
# 119          50130            104
# 120          60730             49
#
# [121 rows x 2 columns]

# %%
df6_def
# Out:
#     순서                   컬럼영문명        컬럼한글명    데이터타입  길이 PK여부 NOT NULL여부
# 0    1            CENTER_SD_CD      센터 시도코드  VARCHAR  10    Y          Y
# 1    2            CENTER_SD_NM       센터 시도명  VARCHAR  40  NaN          Y
# 2    3           CENTER_SGG_CD     센터 시군구코드  VARCHAR  10    Y          Y
# 3    4           CENTER_SGG_NM      센터 시군구명  VARCHAR  40  NaN          Y
# 4    5               TEST_YEAR         측정년도  VARCHAR   4    Y          Y
# 5    6            TEST_ALL_CNT         측정횟수  NUMERIC  22  NaN          Y
# 6    7                MEMB_CNT          회원수  NUMERIC  22  NaN          Y
# 7    8    AGE_GBN_CHILDREN_CNT     유소년 회원 수  NUMERIC  22  NaN          Y
# 8    9       AGE_GBN_YOUTH_CNT     청소년 회원 수  NUMERIC  22  NaN          Y
# 9   10       AGE_GBN_ADULT_CNT      성인 회원 수  NUMERIC  22  NaN          Y
# 10  11     AGE_GBN_CITIZEN_CNT      노인 회원 수  NUMERIC  22  NaN          Y
# 11  12     INPUT_GBN_ADMIN_CNT     관리자 입력건수  NUMERIC  22  NaN          Y
# ...

# %% [markdown]
# ### 지역별 시각화

# %%
state_geo = '/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/CTPRVN_202101/json/TL_SCCO_WFS84.json'

# %%
import requests
import json
from pandas.io.json import json_normalize
import os
import webbrowser
import folium
from folium import plugins
print(folium.__version__)
# Out:
# 0.8.3

# %%
df6['CENTER_SGG_CD'] = df6.CENTER_SD_CD.map(lambda x : str(x).zfill(5))

# %%
# Initialize the map:
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=state_geo,
    data=df6,
    columns=['CENTER_SGG_CD', 'CERT_GBN_GOLD'],
    key_on='feature.CENTER_SGG_CD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'CERT_GBN_GOLD'
)

folium.LayerControl().add_to(m)

# Save to html
m.save('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/CTPRVN_202101/folium_kr.html')
#webbrowser.open_new("folium_kr.html")

# %% [markdown]
# ### 지역별 특정 항목 선택해서 지도상의 시각화 가능함
# (아마도..)

# %% [markdown]
# ## 브레인 스토밍
#
# 1) 개인별 체력수준 파악을 통한 국가, 지역별 의료비 수요 예측
# 2)

# %% [markdown]
# ## 데이터셋 인사이트 정리
#
# 1)
