# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import warnings
warnings.filterwarnings(action='ignore')

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#실행 후 런타임 다시시작

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
c2016 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/가공/체력평가데이터2016')
c2017 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/가공/체력평가데이터2017')
c2018 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/가공/체력평가데이터2018')
c2019 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/가공/체력평가데이터2019')
c2020 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/가공/체력평가데이터2020')
c2021 = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/dataset/가공/체력평가데이터2021')

# %%
c_all = pd.concat([c2016, c2017, c2018, c2019, c2020, c2021])
c_all
# Out:
#        TEST_CNT CENTER_NM AGE_GBN  ... ITEM_F039  ITEM_F040 ITEM_F041
# 0             1        청주      성인  ...      47.7        NaN       NaN
# 1             4        순천      성인  ...       NaN        NaN       NaN
# 2             1        달서      노인  ...      47.4        NaN       NaN
# 3             1    KSPO송파      성인  ...       NaN        NaN       NaN
# 4             1    KSPO송파      성인  ...       NaN        NaN       NaN
# ...         ...       ...     ...  ...       ...        ...       ...
# 84972         1    KSPO송파      성인  ...       NaN      0.370       NaN
# 84973         1    KSPO대구     청소년  ...       NaN        NaN       NaN
# 84974         4    KSPO대구     청소년  ...       NaN        NaN       NaN
# 84975         1    KSPO아산      성인  ...       NaN      0.338       NaN
# 84976         1    동구(부산)      성인  ...       NaN      0.371       NaN
#
# [1116644 rows x 50 columns]

# %%
df = c_all[c_all['CERT_GBN'] == '참가증']
df
# Out:
#        TEST_CNT CENTER_NM AGE_GBN  ... ITEM_F039  ITEM_F040 ITEM_F041
# 3             1    KSPO송파      성인  ...       NaN        NaN       NaN
# 4             1    KSPO송파      성인  ...       NaN        NaN       NaN
# 5             5        금천      노인  ...       NaN        NaN       NaN
# 7             1        금천      성인  ...       NaN        NaN       NaN
# 8             1    KSPO송파      성인  ...       NaN        NaN       NaN
# ...         ...       ...     ...  ...       ...        ...       ...
# 84965         2    KSPO송파      성인  ...       NaN      0.407     0.417
# 84968         1    KSPO송파      성인  ...       NaN      0.405     0.559
# 84969         1    KSPO아산      성인  ...       NaN      0.377       NaN
# 84971         1    KSPO대구      성인  ...       NaN      0.327       NaN
# 84974         4    KSPO대구     청소년  ...       NaN        NaN       NaN
#
# [681862 rows x 50 columns]

# %%
df = df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#         TEST_CNT CENTER_NM AGE_GBN  ... ITEM_F039  ITEM_F040 ITEM_F041
# 0              1    KSPO송파      성인  ...       NaN        NaN       NaN
# 1              1    KSPO송파      성인  ...       NaN        NaN       NaN
# 2              5        금천      노인  ...       NaN        NaN       NaN
# 3              1        금천      성인  ...       NaN        NaN       NaN
# 4              1    KSPO송파      성인  ...       NaN        NaN       NaN
# ...          ...       ...     ...  ...       ...        ...       ...
# 681857         2    KSPO송파      성인  ...       NaN      0.407     0.417
# 681858         1    KSPO송파      성인  ...       NaN      0.405     0.559
# 681859         1    KSPO아산      성인  ...       NaN      0.377       NaN
# 681860         1    KSPO대구      성인  ...       NaN      0.327       NaN
# 681861         4    KSPO대구     청소년  ...       NaN        NaN       NaN
#
# [681862 rows x 50 columns]

# %%
df = df[df['AGE_GBN'] == '성인']
df = df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#         TEST_CNT CENTER_NM AGE_GBN  ... ITEM_F039  ITEM_F040 ITEM_F041
# 0              1    KSPO송파      성인  ...       NaN        NaN       NaN
# 1              1    KSPO송파      성인  ...       NaN        NaN       NaN
# 2              1        금천      성인  ...       NaN        NaN       NaN
# 3              1    KSPO송파      성인  ...       NaN        NaN       NaN
# 4              2        청주      성인  ...      56.2        NaN       NaN
# ...          ...       ...     ...  ...       ...        ...       ...
# 297845         1        익산      성인  ...       NaN      2.553       NaN
# 297846         2    KSPO송파      성인  ...       NaN      0.407     0.417
# 297847         1    KSPO송파      성인  ...       NaN      0.405     0.559
# 297848         1    KSPO아산      성인  ...       NaN      0.377       NaN
# 297849         1    KSPO대구      성인  ...       NaN      0.327       NaN
#
# [297850 rows x 50 columns]

# %%
df =df[[ 'ITEM_F007', 'ITEM_F019', 'ITEM_F020', 'ITEM_F012', 'ITEM_F021', 'ITEM_F022', 'CERT_GBN']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297850 entries, 0 to 297849
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ITEM_F007  297305 non-null  float64
#  1   ITEM_F019  293791 non-null  float64
#  2   ITEM_F020  186350 non-null  float64
#  3   ITEM_F012  296863 non-null  float64
#  4   ITEM_F021  261185 non-null  float64
#  5   ITEM_F022  289657 non-null  float64
#  6   CERT_GBN   297850 non-null  object
# dtypes: float64(6), object(1)
# memory usage: 15.9+ MB

# %%
df = df.dropna(axis=0)

# %%
df = df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ...  ITEM_F021  ITEM_F022  CERT_GBN
# 0            44.2       32.0       23.0  ...      13.12      151.0       참가증
# 1            20.0       20.0        9.0  ...      18.00       99.0       참가증
# 2            24.6        9.0       14.0  ...      15.84      127.0       참가증
# 3            35.2       48.0       36.0  ...      11.15      208.0       참가증
# 4            20.6       14.0       24.0  ...      14.39      136.0       참가증
# ...           ...        ...        ...  ...        ...        ...       ...
# 183448       27.2       20.0       15.0  ...      14.52      125.0       참가증
# 183449       31.1       28.0       30.0  ...      13.21      146.0       참가증
# 183450       18.7       33.0       30.0  ...      14.80      137.0       참가증
# 183451       17.9        0.0        0.0  ...       0.00        0.0       참가증
# 183452       41.9       44.0       24.0  ...       9.87      239.0       참가증
#
# [183453 rows x 7 columns]

# %%
## 0 값을 nan으로 대체후 평균으로 대체
df = df.replace(0, np.NaN)
df = df.fillna(df.mean())
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ...  ITEM_F021   ITEM_F022  CERT_GBN
# 0            44.2  32.000000  23.000000  ...  13.120000  151.000000       참가증
# 1            20.0  20.000000   9.000000  ...  18.000000   99.000000       참가증
# 2            24.6   9.000000  14.000000  ...  15.840000  127.000000       참가증
# 3            35.2  48.000000  36.000000  ...  11.150000  208.000000       참가증
# 4            20.6  14.000000  24.000000  ...  14.390000  136.000000       참가증
# ...           ...        ...        ...  ...        ...         ...       ...
# 183448       27.2  20.000000  15.000000  ...  14.520000  125.000000       참가증
# 183449       31.1  28.000000  30.000000  ...  13.210000  146.000000       참가증
# 183450       18.7  33.000000  30.000000  ...  14.800000  137.000000       참가증
# 183451       17.9  29.024305  24.517889  ...  13.300072  162.740806       참가증
# 183452       41.9  44.000000  24.000000  ...   9.870000  239.000000       참가증
#
# [183453 rows x 7 columns]

# %%
df = df.drop(['CERT_GBN'], axis = 1)

# %%
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021   ITEM_F022
# 0            44.2  32.000000  23.000000   0.700000  13.120000  151.000000
# 1            20.0  20.000000   9.000000  24.800000  18.000000   99.000000
# 2            24.6   9.000000  14.000000  14.300000  15.840000  127.000000
# 3            35.2  48.000000  36.000000  10.800000  11.150000  208.000000
# 4            20.6  14.000000  24.000000   9.700000  14.390000  136.000000
# ...           ...        ...        ...        ...        ...         ...
# 183448       27.2  20.000000  15.000000  11.600000  14.520000  125.000000
# 183449       31.1  28.000000  30.000000  25.600000  13.210000  146.000000
# 183450       18.7  33.000000  30.000000  11.200000  14.800000  137.000000
# 183451       17.9  29.024305  24.517889   9.159875  13.300072  162.740806
# 183452       41.9  44.000000  24.000000  25.500000   9.870000  239.000000
#
# [183453 rows x 6 columns]

# %%
plt.boxplot(df['ITEM_F007'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3d008fb610>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3d009016d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3d00908710>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3d009081d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3d008fbc10>,
#   <matplotlib.lines.Line2D at 0x7f3d00901190>]}

# %%
df[df['ITEM_F007'] < 0]
# Out:
#        ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022
# 94527    -9999.0        2.0  24.517889       18.7      16.12      129.0
# 94528    -9999.0       36.0  24.517889       -0.6      11.92      185.0

# %%
index_7 = df[df['ITEM_F007'] < 0].index
df = df.drop(index_7)

# %%
plt.boxplot(df['ITEM_F007'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3d00862790>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3d008667d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3d0086c810>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3d0086c2d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3d00862d10>,
#   <matplotlib.lines.Line2D at 0x7f3d00866290>]}

# %%
index_7 = df[df['ITEM_F007'] > 80].index
df = df.drop(index_7)

# %%
plt.boxplot(df['ITEM_F007'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3d00844b90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3d0084bbd0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3d00852c10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3d008526d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3d0084b150>,
#   <matplotlib.lines.Line2D at 0x7f3d0084b690>]}

# %%
plt.boxplot(df['ITEM_F019'])
plt.show()

# %%
df[df['ITEM_F019'] > 100]
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022
# 52669        39.6      625.0       41.0       26.2       9.11      225.0
# 76627        28.0      302.0       19.0        2.9      12.64      178.0
# 138613       40.8      448.0       28.0       13.6       9.84      211.0
# 164793       20.8      287.0       21.0        8.2      14.19      140.0

# %%
index_19 = df[df['ITEM_F019'] > 100].index
df = df.drop(index_19)

# %%
plt.boxplot(df['ITEM_F019'])
plt.show()

# %%
plt.boxplot(df['ITEM_F020'])
plt.show()

# %%
plt.boxplot(df['ITEM_F012'])
plt.show()

# %%
df[df['ITEM_F012'] > 50]
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022
# 13856        23.5       12.0        8.0      125.0      13.63      106.0
# 21237        33.9       22.0       15.0      157.7      13.00      191.0
# 30605        43.9       51.0       41.0       55.1       9.69      233.0
# 43370        37.9       19.0       21.0      705.0      13.75      166.0
# 43382        46.2       41.0       35.0      127.0      11.02      218.0
# 46627        26.2       25.0       11.0      226.0      15.20      155.0
# 54522        49.8       60.0       53.0      165.0      10.44      216.0
# 74385        18.0       35.0       12.0      122.4      12.99      135.0
# 80852        27.0        7.0       12.0      131.0      15.32      131.0
# 106489       18.8       21.0       20.0       86.0      11.90      142.0
# 106871       23.7       15.0       16.0      148.0      13.96      134.0
# 107102       24.7        6.0       10.0      139.0      17.58      112.0
# ...

# %%
index_12 = df[df['ITEM_F012'] > 50].index
df = df.drop(index_12)

# %%
plt.boxplot(df['ITEM_F012'])
plt.show()

# %%
df[df['ITEM_F012'] < -30]
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022
# 45811        22.6  57.000000       46.0      -40.0      10.35      230.0
# 57174        15.5   1.000000        7.0      -50.0      28.24      100.0
# 58216        29.0  54.000000       25.0      -50.0      11.46      180.0
# 58401        16.6  13.000000       15.0      -50.0      18.66      107.0
# 138787       32.2  29.024305        4.0     -114.0      17.99       97.0

# %%
index_12 = df[df['ITEM_F012'] < -30].index
df = df.drop(index_12)

# %%
plt.boxplot(df['ITEM_F012'])
plt.show()

# %%
plt.boxplot(df['ITEM_F021'])
plt.show()

# %%
df[df['ITEM_F021'] > 100]
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022
# 54958        36.7  46.000000       61.0        5.1     1065.0      184.0
# 86717        19.5  18.000000       14.0       26.0      167.0      125.0
# 94947         4.8  29.024305        4.0        1.3      229.3      114.0
# 118356       41.8  21.000000       23.0        4.5     1260.0      194.0
# 129145       21.0   6.000000       11.0        9.2      181.0      114.0
# 182760       46.2  65.000000       41.0        1.6     1098.0      210.0

# %%
index_21 = df[df['ITEM_F021'] > 100].index
df = df.drop(index_21)

# %%
plt.boxplot(df['ITEM_F021'])
plt.show()

# %%
plt.boxplot(df['ITEM_F022'])
plt.show()

# %%
index_22 = df[df['ITEM_F022'] > 500].index
df = df.drop(index_22)

# %%
plt.boxplot(df['ITEM_F022'])
plt.show()

# %%
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021   ITEM_F022
# 0            44.2  32.000000  23.000000   0.700000  13.120000  151.000000
# 1            20.0  20.000000   9.000000  24.800000  18.000000   99.000000
# 2            24.6   9.000000  14.000000  14.300000  15.840000  127.000000
# 3            35.2  48.000000  36.000000  10.800000  11.150000  208.000000
# 4            20.6  14.000000  24.000000   9.700000  14.390000  136.000000
# ...           ...        ...        ...        ...        ...         ...
# 183448       27.2  20.000000  15.000000  11.600000  14.520000  125.000000
# 183449       31.1  28.000000  30.000000  25.600000  13.210000  146.000000
# 183450       18.7  33.000000  30.000000  11.200000  14.800000  137.000000
# 183451       17.9  29.024305  24.517889   9.159875  13.300072  162.740806
# 183452       41.9  44.000000  24.000000  25.500000   9.870000  239.000000
#
# [183403 rows x 6 columns]

# %%
df = df.reset_index()
df = df.drop(['index'], axis = 1)
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021   ITEM_F022
# 0            44.2  32.000000  23.000000   0.700000  13.120000  151.000000
# 1            20.0  20.000000   9.000000  24.800000  18.000000   99.000000
# 2            24.6   9.000000  14.000000  14.300000  15.840000  127.000000
# 3            35.2  48.000000  36.000000  10.800000  11.150000  208.000000
# 4            20.6  14.000000  24.000000   9.700000  14.390000  136.000000
# ...           ...        ...        ...        ...        ...         ...
# 183398       27.2  20.000000  15.000000  11.600000  14.520000  125.000000
# 183399       31.1  28.000000  30.000000  25.600000  13.210000  146.000000
# 183400       18.7  33.000000  30.000000  11.200000  14.800000  137.000000
# 183401       17.9  29.024305  24.517889   9.159875  13.300072  162.740806
# 183402       41.9  44.000000  24.000000  25.500000   9.870000  239.000000
#
# [183403 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler

df = StandardScaler().fit_transform(df) 
df=pd.DataFrame(df,columns=['ITEM_F007', 'ITEM_F019', 'ITEM_F020', 'ITEM_F012', 'ITEM_F021', 'ITEM_F022'])
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022
# 0        1.288440   0.202999  -0.093370  -0.886564  -0.061095  -0.269688
# 1       -1.061403  -0.613342  -0.954542   1.641785   1.819535  -1.467555
# 2       -0.614739  -1.361655  -0.646980   0.540222   0.987125  -0.822550
# 3        0.414531   1.291455   0.706290   0.173035  -0.820283   1.043358
# 4       -1.003142  -1.021513  -0.031858   0.057633   0.428332  -0.615227
# ...           ...        ...        ...        ...        ...        ...
# 183398  -0.362276  -0.613342  -0.585468   0.256963   0.478430  -0.868622
# 183399   0.016418  -0.069114   0.337216   1.725714  -0.026411  -0.384868
# 183400  -1.187634   0.271028   0.337216   0.214999   0.586335  -0.592191
# 183401  -1.265315   0.000567  -0.000001   0.000968   0.008301   0.000772
# 183402   1.065108   1.019341  -0.031858   1.715223  -1.313563   1.757471
#
# [183403 rows x 6 columns]

# %%
from sklearn.cluster import KMeans

# %%
distortions = []
for i in range(1, 11):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(df)
    distortions.append(km.inertia_) 
    
    
    # 군집 내 분산, 적을수록 좋음

# plot - 급격하게 줄어드는 부분
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(df)

# 결과 확인
result_by_sklearn = df.copy()
result_by_sklearn["cluster"] = kmeans.labels_
result_by_sklearn.head()
# Out:
#    ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021  ITEM_F022  cluster
# 0   1.288440   0.202999  -0.093370  -0.886564  -0.061095  -0.269688        2
# 1  -1.061403  -0.613342  -0.954542   1.641785   1.819535  -1.467555        0
# 2  -0.614739  -1.361655  -0.646980   0.540222   0.987125  -0.822550        0
# 3   0.414531   1.291455   0.706290   0.173035  -0.820283   1.043358        1
# 4  -1.003142  -1.021513  -0.031858   0.057633   0.428332  -0.615227        3

# %%
result_by_sklearn
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ...  ITEM_F021  ITEM_F022  cluster
# 0        1.288440   0.202999  -0.093370  ...  -0.061095  -0.269688        2
# 1       -1.061403  -0.613342  -0.954542  ...   1.819535  -1.467555        0
# 2       -0.614739  -1.361655  -0.646980  ...   0.987125  -0.822550        0
# 3        0.414531   1.291455   0.706290  ...  -0.820283   1.043358        1
# 4       -1.003142  -1.021513  -0.031858  ...   0.428332  -0.615227        3
# ...           ...        ...        ...  ...        ...        ...      ...
# 183398  -0.362276  -0.613342  -0.585468  ...   0.478430  -0.868622        3
# 183399   0.016418  -0.069114   0.337216  ...  -0.026411  -0.384868        3
# 183400  -1.187634   0.271028   0.337216  ...   0.586335  -0.592191        3
# 183401  -1.265315   0.000567  -0.000001  ...   0.008301   0.000772        3
# 183402   1.065108   1.019341  -0.031858  ...  -1.313563   1.757471        1
#
# [183403 rows x 7 columns]

# %%
df_0 = result_by_sklearn[result_by_sklearn['cluster'] == 0]
df_1 = result_by_sklearn[result_by_sklearn['cluster'] == 1]
df_2 = result_by_sklearn[result_by_sklearn['cluster'] == 2]
df_3 = result_by_sklearn[result_by_sklearn['cluster'] == 3]

# %%
label = result_by_sklearn['cluster']

# %%
df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ITEM_F012  ITEM_F021   ITEM_F022
# 0            44.2  32.000000  23.000000   0.700000  13.120000  151.000000
# 1            20.0  20.000000   9.000000  24.800000  18.000000   99.000000
# 2            24.6   9.000000  14.000000  14.300000  15.840000  127.000000
# 3            35.2  48.000000  36.000000  10.800000  11.150000  208.000000
# 4            20.6  14.000000  24.000000   9.700000  14.390000  136.000000
# ...           ...        ...        ...        ...        ...         ...
# 183398       27.2  20.000000  15.000000  11.600000  14.520000  125.000000
# 183399       31.1  28.000000  30.000000  25.600000  13.210000  146.000000
# 183400       18.7  33.000000  30.000000  11.200000  14.800000  137.000000
# 183401       17.9  29.024305  24.517889   9.159875  13.300072  162.740806
# 183402       41.9  44.000000  24.000000  25.500000   9.870000  239.000000
#
# [183403 rows x 6 columns]

# %%
label
# Out:
# 0         2
# 1         0
# 2         0
# 3         1
# 4         3
#          ..
# 183398    3
# 183399    3
# 183400    3
# 183401    3
# 183402    1
# Name: cluster, Length: 183403, dtype: int32

# %%
final_df = pd.concat([df, label], axis =1 )
final_df
# Out:
#         ITEM_F007  ITEM_F019  ITEM_F020  ...  ITEM_F021   ITEM_F022  cluster
# 0            44.2  32.000000  23.000000  ...  13.120000  151.000000        2
# 1            20.0  20.000000   9.000000  ...  18.000000   99.000000        0
# 2            24.6   9.000000  14.000000  ...  15.840000  127.000000        0
# 3            35.2  48.000000  36.000000  ...  11.150000  208.000000        1
# 4            20.6  14.000000  24.000000  ...  14.390000  136.000000        3
# ...           ...        ...        ...  ...        ...         ...      ...
# 183398       27.2  20.000000  15.000000  ...  14.520000  125.000000        3
# 183399       31.1  28.000000  30.000000  ...  13.210000  146.000000        3
# 183400       18.7  33.000000  30.000000  ...  14.800000  137.000000        3
# 183401       17.9  29.024305  24.517889  ...  13.300072  162.740806        3
# 183402       41.9  44.000000  24.000000  ...   9.870000  239.000000        1
#
# [183403 rows x 7 columns]

# %%
final_df.columns = ['근력', '근지구력', '심폐지구력', '유연성', '민첩성', '순발력', 'cluster']
final_df
# Out:
#           근력       근지구력      심폐지구력        유연성        민첩성         순발력  cluster
# 0       44.2  32.000000  23.000000   0.700000  13.120000  151.000000        2
# 1       20.0  20.000000   9.000000  24.800000  18.000000   99.000000        0
# 2       24.6   9.000000  14.000000  14.300000  15.840000  127.000000        0
# 3       35.2  48.000000  36.000000  10.800000  11.150000  208.000000        1
# 4       20.6  14.000000  24.000000   9.700000  14.390000  136.000000        3
# ...      ...        ...        ...        ...        ...         ...      ...
# 183398  27.2  20.000000  15.000000  11.600000  14.520000  125.000000        3
# 183399  31.1  28.000000  30.000000  25.600000  13.210000  146.000000        3
# 183400  18.7  33.000000  30.000000  11.200000  14.800000  137.000000        3
# 183401  17.9  29.024305  24.517889   9.159875  13.300072  162.740806        3
# 183402  41.9  44.000000  24.000000  25.500000   9.870000  239.000000        1
#
# [183403 rows x 7 columns]

# %%
final_df.to_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/k-means.csv')

# %%
final_df = pd.read_csv('/content/drive/MyDrive/국민체력 100 빅데이터활용 공모전/k-means.csv') 
final_df = final_df.drop(['Unnamed: 0'], axis = 1)
final_df
# Out:
#           근력       근지구력      심폐지구력        유연성        민첩성         순발력  cluster
# 0       44.2  32.000000  23.000000   0.700000  13.120000  151.000000        2
# 1       20.0  20.000000   9.000000  24.800000  18.000000   99.000000        0
# 2       24.6   9.000000  14.000000  14.300000  15.840000  127.000000        0
# 3       35.2  48.000000  36.000000  10.800000  11.150000  208.000000        1
# 4       20.6  14.000000  24.000000   9.700000  14.390000  136.000000        3
# ...      ...        ...        ...        ...        ...         ...      ...
# 183398  27.2  20.000000  15.000000  11.600000  14.520000  125.000000        3
# 183399  31.1  28.000000  30.000000  25.600000  13.210000  146.000000        3
# 183400  18.7  33.000000  30.000000  11.200000  14.800000  137.000000        3
# 183401  17.9  29.024305  24.517889   9.159875  13.300072  162.740806        3
# 183402  41.9  44.000000  24.000000  25.500000   9.870000  239.000000        1
#
# [183403 rows x 7 columns]

# %%
df_0 = final_df[final_df['cluster'] == 0]
df_1 = final_df[final_df['cluster'] == 1]
df_2 = final_df[final_df['cluster'] == 2]
df_3 = final_df[final_df['cluster'] == 3]

# %%
plt.boxplot(final_df['근력'])
plt.show()

# %%
final_df['근력'].describe()
# Out:
# count    183403.000000
# mean         30.930923
# std          10.298591
# min           0.300000
# 25%          22.400000
# 50%          29.600000
# 75%          39.100000
# max          76.000000
# Name: 근력, dtype: float64

# %%
plt.boxplot(final_df['근지구력'])
plt.show()

# %%
final_df['근지구력'].describe()
# Out:
# count    183403.000000
# mean         29.015964
# std          14.699772
# min           1.000000
# 25%          18.000000
# 50%          29.024305
# 75%          40.000000
# max         100.000000
# Name: 근지구력, dtype: float64

# %%
plt.boxplot(final_df['심폐지구력'])
plt.show()

# %%
final_df['심폐지구력'].describe()
# Out:
# count    183403.000000
# mean         24.517907
# std          16.256961
# min          -6.700000
# 25%          12.000000
# 50%          20.000000
# 75%          33.000000
# max         140.000000
# Name: 심폐지구력, dtype: float64

# %%
plt.boxplot(final_df['유연성'])
plt.show()

# %%
final_df['유연성'].describe()
# Out:
# count    183403.000000
# mean          9.150650
# std           9.531936
# min         -30.000000
# 25%           3.300000
# 50%           9.500000
# 75%          16.000000
# max          47.000000
# Name: 유연성, dtype: float64

# %%
plt.boxplot(final_df['민첩성'])
plt.show()

# %%
final_df['민첩성'].describe()
# Out:
# count    183403.000000
# mean         13.278533
# std           2.594882
# min           0.170000
# 25%          11.310000
# 50%          13.020000
# 75%          14.660000
# max          60.000000
# Name: 민첩성, dtype: float64

# %%
df_0.mean()
# Out:
# 근력          21.630452
# 근지구력        13.773221
# 심폐지구력       10.489811
# 유연성          8.299276
# 민첩성         16.680614
# 순발력        109.459016
# cluster      0.000000
# dtype: float64

# %%
df_1.mean()
# Out:
# 근력          40.797474
# 근지구력        45.184147
# 심폐지구력       44.302783
# 유연성          9.348576
# 민첩성         10.821292
# 순발력        211.488523
# cluster      1.000000
# dtype: float64

# %%
df_2.mean()
# Out:
# 근력          36.875979
# 근지구력        31.478784
# 심폐지구력       23.870325
# 유연성          1.452905
# 민첩성         12.457964
# 순발력        179.629610
# cluster      2.000000
# dtype: float64

# %%
df_3.mean()
# Out:
# 근력          24.088828
# 근지구력        23.488652
# 심폐지구력       17.345809
# 유연성         15.586081
# 민첩성         13.700138
# 순발력        143.748598
# cluster      3.000000
# dtype: float64
